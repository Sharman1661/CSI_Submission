# %%
import zipfile
import os

zip_file_path = '/content/pothole.v1i.yolov8.zip'
extract_dir = '/content/pothole_dataset'

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"File '{zip_file_path}' unzipped to '{extract_dir}' successfully.")

print(f"Contents of '{extract_dir}':")
for root, dirs, files in os.walk(extract_dir):
    level = root.replace(extract_dir, '').count(os.sep)
    indent = ' ' * 4 * (level)
    print(f"{indent}{os.path.basename(root)}/")
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print(f"{subindent}{f}")
# Out:
# File '/content/pothole.v1i.yolov8.zip' unzipped to '/content/pothole_dataset' successfully.
# Contents of '/content/pothole_dataset':
# pothole_dataset/
#     README.dataset.txt
#     data.yaml
#     README.roboflow.txt
#     train/
#         images/
#             youtube-24_jpg.rf.09b398c4189ce36a2886ed9fd317d61e.jpg
#             images212_jpg.rf.6b79e054eb84c67986abe25e48a389cc.jpg
#             youtube-27_jpg.rf.a97df152c3270edb7223227c81a73532.jpg
#             youtube-29_jpg.rf.51fff8f9bb2fd99b877a8d56df2c46de.jpg
#             images199_jpg.rf.d861b7953fa0e44e424d2ff5871b5417.jpg
#             youtube-30_jpg.rf.9ebf1504dfd9e2ecb3f7232d4deaf382.jpg
#             images208_jpg.rf.c3358e930efa9ba7c414a049dc244481.jpg
#             images220_jpg.rf.3f282d0f5d537187d62fb993cd14b1e6.jpg
#             youtube-31_jpg.rf.9bb4439ea0fcb80d548428cadee83988.jpg
#             youtube-29_jpg.rf.4816e2f66b30c9541067cee53b7f4098.jpg
# ...

# %%
# !pip install ultralytics

from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(data='/content/pothole_dataset/data.yaml', epochs=30, imgsz=640)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
